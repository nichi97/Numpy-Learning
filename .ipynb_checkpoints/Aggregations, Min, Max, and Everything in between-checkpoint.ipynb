# %% [markdown]
# # Summing the values in an array

# %%
import numpy as np

# %%
L = np.random.random(100)
sum(L)
# Out:
# 51.368573198627665

# %%
np.sum(L)
# Out:
# 51.36857319862766

# %%
# numpy sum is much faster!
big_array = np.random.rand(1000000)
# %timeit sum(big_array)
# %timeit np.sum(big_array)
# Out:
# 415 ms ± 35.4 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# 2.35 ms ± 464 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %% [markdown]
# # Minimum and Maximum

# %%
# same thing with np.min and np.max
min(big_array), max(big_array)
# Out:
# (7.225280789224797e-07, 0.9999998903257317)

# %%
np.min(big_array), np.max(big_array)
# Out:
# (7.225280789224797e-07, 0.9999998903257317)

# %%
# %timeit min(big_array)
# %timeit np.min(big_array)
# Out:
# 321 ms ± 24.4 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# 944 µs ± 41.6 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)

# %%
# a shorter syntax is to use methods of the array object itself
print(big_array.min(), big_array.max(), big_array.sum())

# %% [markdown]
# ## Multi dimentioinal aggregates

# %%
M = np.random.random((3,4))
print(M)
# Out:
# [[0.52557119 0.4495864  0.51359467 0.88446533]
#  [0.18131487 0.23534669 0.52848228 0.22753313]
#  [0.45098997 0.66383176 0.28547623 0.28662711]]

# %%
M.sum()
# Out:
# 5.232819621440296

# %%
M.min(axis=0)
# Out:
# array([0.18131487, 0.23534669, 0.28547623, 0.22753313])

# %%
# axis epecify the dimension of the array that will be collapsed
M.max(axis=1)
# Out:
# array([0.88446533, 0.52848228, 0.66383176])

# %% [markdown]
# ## Other aggregation functions

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
M
# Out:
# array([[0.52557119, 0.4495864 , 0.51359467, 0.88446533],
#        [0.18131487, 0.23534669, 0.52848228, 0.22753313],
#        [0.45098997, 0.66383176, 0.28547623, 0.28662711]])

# %%
M.sort()
print(M)
# Out:
# [[0.4495864  0.51359467 0.52557119 0.88446533]
#  [0.18131487 0.22753313 0.23534669 0.52848228]
#  [0.28547623 0.28662711 0.45098997 0.66383176]]

# %%
np.percentile(M, 99)
# Out:
# 0.8601956350033503

# %% [markdown]
# # Example: What is the average height of US Presidents?

# %%
heightStr = "189 170 189 163 183 171 185 168 173 183 173 173 175 178 183 193 178 173 174 183 183 168 170 178 182 180 183 178 182 188 175 179 183 193 182 183 177 185 188 188 182 185"

# Question 1: How would you convert this string into numpy array?

# Question 2: How to find the mean, std, min, and max of these data? 

# Question 3: Compute the 25th percentil, median, and 75th percentile of these data

# %%
import matplotlib.pyplot as plt
import seaborn; seaborn.set()  # set plot style
plt.hist(height)
plt.title('Height Distribution of US Presidents')
plt.xlabel('height (cm)')
plt.ylabel('number');

# %%
ls
# Out:
# array([189, 170, 189, 163, 183, 171, 185, 168, 173, 183, 173, 173, 175,
#        178, 183, 193, 178, 173, 174, 183, 183, 168, 170, 178, 182, 180,
#        183, 178, 182, 188, 175, 179, 183, 193, 182, 183, 177, 185, 188,
#        188, 182, 185])
